# %%
import pandas as pd
import numpy as np

#input the clean df (with only id, d, features, and sales)
def df_to_tensor(df, validation_day, train_day):
    # Read the CSV file
    df = df[(df['d'] > 1941 - validation_day - train_day) & (df['d'] <= 1941)]
    # Get unique ids, d values, and column names
    ids = df['id'].unique()

    columns = [col for col in df.columns if col not in ['id', 'd']]

    d_values_train = range(1941 - validation_day - train_day + 1, 1941 - validation_day + 1)
    d_values_validation = range(1941 - validation_day + 1, 1941 + 1)

    # Initialize the tensor
    num_ids = len(ids)
    num_d_values = len(d_values_train)
    depth = len(columns)

    tensor = np.zeros((num_ids, num_d_values, depth))

    # Initialize the sales tensor
    sales_tensor = np.zeros((num_ids, len(d_values_validation)))

    # Fill the tensor and sales_tensor
    for i, id_val in enumerate(ids):
        for j, d_val in enumerate(d_values_train):
            for k, col in enumerate(columns):
                value = df[(df['id'] == id_val) & (df['d'] == d_val)][col].values
                if len(value) > 0:
                    tensor[i, j, k] = value[0]
        
        # Fill sales_tensor
        for j, d_val in enumerate(d_values_validation):
            sales_value = df[(df['id'] == id_val) & (df['d'] == d_val)]['sales'].values
            if len(sales_value) > 0:
                sales_tensor[i, j] = sales_value[0]

    return tensor, sales_tensor

# Example usage:
# tensor, sales_tensor = df_to_tensor(df, lag_day)

def df_to_tensor_test(df, train_day):
    # Read the CSV file
    df = df[(df['d'] > 1941 - train_day) & (df['d'] <= 1941)]
    # Get unique ids, d values, and column names
    ids = df['id'].unique()

    columns = [col for col in df.columns if col not in ['id', 'd']]

    d_values_train = range(1941 - train_day + 1, 1941 + 1)

    # Initialize the tensor
    num_ids = len(ids)
    num_d_values = len(d_values_train)
    depth = len(columns)

    tensor = np.zeros((num_ids, num_d_values, depth))

    # Fill the tensor and sales_tensor
    for i, id_val in enumerate(ids):
        for j, d_val in enumerate(d_values_train):
            for k, col in enumerate(columns):
                value = df[(df['id'] == id_val) & (df['d'] == d_val)][col].values
                if len(value) > 0:
                    tensor[i, j, k] = value[0]
    
    return tensor, ids

# %%
#load data
import numpy as np
import pandas as pd
import os, sys, gc, time, warnings, pickle, psutil, random

raw_data_dir = '..\datasets\sales_train_evaluation.csv'
processed_data_dir = '..\datasets\\'
ORIGINAL = raw_data_dir
BASE     = processed_data_dir+'grid_part_1.pkl'
PRICE    = processed_data_dir+'grid_part_2.pkl'
CALENDAR = processed_data_dir+'grid_part_3.pkl'
LAGS     = processed_data_dir+'lags_df_28.pkl'
MEAN_ENC = processed_data_dir+'mean_encoding_df.pkl'

STORES_IDS = ['CA_1','CA_2','CA_3','CA_4','TX_1','TX_2','TX_3','WI_1','WI_2','WI_3']

#LIMITS and const
TARGET      = 'sales'            
START_TRAIN = 0                  
END_TRAIN   = 1941
P_HORIZON   = 28

mean_features   = ['enc_cat_id_mean','enc_cat_id_std',
                   'enc_dept_id_mean','enc_dept_id_std',
                   'enc_item_id_mean','enc_item_id_std'] 

remove_features = [TARGET,'id','state_id','store_id',
                    'item_id', 'dept_id', 'cat_id','date','wm_yr_wk','d', \
                    'release', 'price_min','price_max',  \
                    'price_norm', 'price_nunique', 'item_nunique','price_std', \
                    'price_momentum', 'price_momentum_y',  'price_momentum_m', 'price_mean', \
                    'tm_d', 'tm_w', 'tm_m', 'tm_y', 'tm_wm', 'tm_dw', 'tm_w_end', \
                    'enc_cat_id_std', 'event_type_1', 'event_name_2', 'event_type_2', \
                    'enc_dept_id_std', 'enc_item_id_std', \
                    'rolling_std_7', 'rolling_std_14', \
                    'rolling_std_30', 'rolling_mean_tmp_1_7', 'rolling_mean_tmp_1_14', \
                    'rolling_mean_tmp_1_30', 'rolling_mean_tmp_7_7', \
                    'rolling_mean_tmp_7_14', 'rolling_mean_tmp_7_30', \
                    'rolling_mean_tmp_14_7', 'rolling_mean_tmp_14_14', \
                    'sales_lag_36', 'sales_lag_37', 'sales_lag_38', 'sales_lag_39', 'sales_lag_40', 'sales_lag_41', 'sales_lag_42', \
                    'rolling_mean_7', 'rolling_mean_14', 'rolling_mean_30', 'rolling_mean_60', 'rolling_std_60', 'rolling_mean_180', 'rolling_std_180', 'rolling_mean_tmp_1_60', 'rolling_mean_tmp_7_60', 'rolling_mean_tmp_14_60', \
                    'rolling_mean_tmp_14_30','sales_lag_28', 'sales_lag_29', 'sales_lag_30', 'sales_lag_31', 'sales_lag_32', \
                    'sales_lag_33', 'sales_lag_34', 'sales_lag_35']

# Read data
def get_data_by_store(store):
    
    # Read and contact basic feature
    df = pd.concat([pd.read_pickle(BASE),
                    pd.read_pickle(PRICE).iloc[:,2:],
                    pd.read_pickle(CALENDAR).iloc[:,2:]],
                    axis=1)
    

    df = df[df['d']>=START_TRAIN]
    
    df = df[df['store_id']==store]

    df2 = pd.read_pickle(MEAN_ENC)[mean_features]
    df2 = df2[df2.index.isin(df.index)]
    
    df3 = pd.read_pickle(LAGS).iloc[:,3:]
    df3 = df3[df3.index.isin(df.index)]
    
    df = pd.concat([df, df2], axis=1)
    del df2
    
    df = pd.concat([df, df3], axis=1)
    del df3

    state = "snap_" + store.split('_')[0]
    states = ['snap_CA','snap_TX','snap_WI']
    deleted_states = []
    for i in states:
        if i != state:
            deleted_states.append(i)
            
    features = ['event_name_1_lag'] + [col for col in list(df) if (col not in remove_features and col not in deleted_states)]
    
    df['event_name_1'] = df['event_name_1'].notnull().astype(int)

    # and 'time' is the column indicating the time point
    lag = 1  # Define the lag you want, e.g., lag of 1 time point

    # Sort the DataFrame by 'id' and 'time' columns
    df = df.sort_values(by=['id', 'd'])

    # Create the lagged column
    df['event_name_1_lag'] = df.groupby('id')['event_name_1'].shift(lag)

    df = df[['id','d',TARGET]+features]
    
    df = df.reset_index(drop=True)
    
    return df, features

# Recombine Test set after training
def get_base_test():
    base_test = pd.DataFrame()

    for store_id in STORES_IDS:
        temp_df = pd.read_pickle(processed_data_dir+'test_'+store_id+'.pkl')
        temp_df['store_id'] = store_id
        base_test = pd.concat([base_test, temp_df]).reset_index(drop=True)
    
    return base_test

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.layers import MultiHeadAttention, LayerNormalization

# Assuming tensor_train is already created as per the previous code snippets
# tensor_train shape: (num_ids, num_d_values, depth)
for store_id in STORES_IDS:
    df, features = get_data_by_store(store_id)
    tensor_train, tensor_label = df_to_tensor(df, train_day=56, validation_day= 28)

    # Save tensor_train as a pickle file
    np.save(f'tensor_train_{store_id}.npy', tensor_train)
    # Save tensor_label as a pickle file
    np.save(f'tensor_label_{store_id}.npy', tensor_label)
    # Reshape the tensor_train to fit the Transformer input shape
    num_ids, num_d_values, depth = tensor_train.shape
    input_shape = (num_d_values, depth)

    # Define the Transformer model with linear output
    def transformer_model(input_shape):
        inputs = Input(shape=input_shape)
        # Transformer layers
        transformer_layer = MultiHeadAttention(num_heads=12, key_dim=depth)
        x = transformer_layer(inputs, inputs)
        x = LayerNormalization(epsilon=1e-6)(x)
        x = Dropout(0.2)(x)
        # Flatten the output
        x = tf.keras.layers.Flatten()(x)
        outputs = Dense(28, activation='linear')(x)  # Linear activation for continuous output
        model = Model(inputs=inputs, outputs=outputs)
        return model

    # Instantiate the model
    model = transformer_model(input_shape)

    from tensorflow.keras.callbacks import EarlyStopping

    # Define early stopping criteria
    early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

    # Compile the model
    model.compile(optimizer='adam', loss='mean_squared_error')  # Use mean squared error for regression

    # Train the model (assuming you have labels for training)
    # Replace tensor_train and y_train with your actual training data and labels
    model.fit(tensor_train, tensor_label, epochs=200, batch_size=50, validation_split=0.2, callbacks=[early_stopping])

    # Save the model
    model.save(f"transformer_model_{store_id}_12heads.h5")
# Out:
# C:\Users\Yuhui Lin\AppData\Local\Temp\ipykernel_25944\157111123.py:89: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df['event_name_1_lag'] = df.groupby('id')['event_name_1'].shift(lag)
# Epoch 1/200
# 49/49 [==============================] - 5s 37ms/step - loss: 13.4173 - val_loss: 1.1351
# Epoch 2/200
# 49/49 [==============================] - 1s 28ms/step - loss: 9.9625 - val_loss: 1.1133
# Epoch 3/200
# 49/49 [==============================] - 1s 21ms/step - loss: 9.2881 - val_loss: 1.0412
# Epoch 4/200
# 49/49 [==============================] - 1s 27ms/step - loss: 8.6436 - val_loss: 1.2645
# Epoch 5/200
# 49/49 [==============================] - 1s 23ms/step - loss: 8.3594 - val_loss: 1.0458
# Epoch 6/200
# 49/49 [==============================] - 1s 27ms/step - loss: 8.0665 - val_loss: 1.2850
# Epoch 7/200
# 49/49 [==============================] - 1s 25ms/step - loss: 7.6310 - val_loss: 1.1589
# Epoch 8/200
# 49/49 [==============================] - 1s 26ms/step - loss: 7.5788 - val_loss: 2.1402
# Epoch 9/200
# 49/49 [==============================] - 1s 28ms/step - loss: 7.5345 - val_loss: 1.2435
# Epoch 10/200
# 49/49 [==============================] - 1s 28ms/step - loss: 7.1932 - val_loss: 1.1882
# Epoch 11/200
# 49/49 [==============================] - 1s 27ms/step - loss: 7.1385 - val_loss: 1.3030
# Epoch 12/200
# 49/49 [==============================] - 1s 28ms/step - loss: 6.8784 - val_loss: 1.2439
# Epoch 13/200
# 49/49 [==============================] - 1s 25ms/step - loss: 6.9009 - val_loss: 1.2117
# Epoch 14/200
# 49/49 [==============================] - 1s 26ms/step - loss: 7.0345 - val_loss: 1.0625
# Epoch 15/200
# 49/49 [==============================] - 1s 26ms/step - loss: 6.6963 - val_loss: 1.4154
# Epoch 16/200
# 49/49 [==============================] - 1s 23ms/step - loss: 6.8104 - val_loss: 1.4382
# Epoch 17/200
# 49/49 [==============================] - 1s 26ms/step - loss: 6.6384 - val_loss: 1.2911
# Epoch 18/200
# 49/49 [==============================] - 1s 28ms/step - loss: 6.4677 - val_loss: 1.1556
# Epoch 19/200
# 49/49 [==============================] - 1s 28ms/step - loss: 6.4312 - val_loss: 1.0517
# Epoch 20/200
# 49/49 [==============================] - 1s 28ms/step - loss: 6.4142 - val_loss: 1.0777
# Epoch 21/200
# 49/49 [==============================] - 1s 28ms/step - loss: 6.4291 - val_loss: 1.0138
# Epoch 22/200
# 49/49 [==============================] - 1s 27ms/step - loss: 6.5120 - val_loss: 1.2062
# Epoch 23/200
# 49/49 [==============================] - 1s 28ms/step - loss: 6.2374 - val_loss: 1.0210
# Epoch 24/200
# 49/49 [==============================] - 1s 22ms/step - loss: 6.3780 - val_loss: 1.0330
# Epoch 25/200
# 49/49 [==============================] - 1s 27ms/step - loss: 6.4521 - val_loss: 1.4965
# Epoch 26/200
# 49/49 [==============================] - 1s 27ms/step - loss: 6.2502 - val_loss: 1.0246
# Epoch 27/200
# 49/49 [==============================] - 1s 28ms/step - loss: 6.1264 - val_loss: 1.0977
# Epoch 28/200
# 49/49 [==============================] - 1s 28ms/step - loss: 6.0388 - val_loss: 1.1977
# Epoch 29/200
# 49/49 [==============================] - 1s 28ms/step - loss: 5.9989 - val_loss: 1.0612
# Epoch 30/200
# 49/49 [==============================] - 1s 28ms/step - loss: 5.9306 - val_loss: 0.9939
# Epoch 31/200
# 49/49 [==============================] - 1s 29ms/step - loss: 5.8706 - val_loss: 1.1320
# Epoch 32/200
# 49/49 [==============================] - 1s 22ms/step - loss: 5.8842 - val_loss: 1.0779
# Epoch 33/200
# 49/49 [==============================] - 1s 26ms/step - loss: 6.0275 - val_loss: 1.2927
# Epoch 34/200
# 49/49 [==============================] - 1s 29ms/step - loss: 6.0321 - val_loss: 1.3899
# Epoch 35/200
# 49/49 [==============================] - 1s 28ms/step - loss: 5.9389 - val_loss: 0.9963
# Epoch 36/200
# 49/49 [==============================] - 1s 26ms/step - loss: 5.7536 - val_loss: 1.2392
# Epoch 37/200
# 49/49 [==============================] - 1s 29ms/step - loss: 5.9997 - val_loss: 1.4509
# Epoch 38/200
# 49/49 [==============================] - 1s 28ms/step - loss: 5.9570 - val_loss: 1.1355
# Epoch 39/200
# 49/49 [==============================] - 1s 28ms/step - loss: 5.8473 - val_loss: 1.0904
# Epoch 40/200
# 49/49 [==============================] - 1s 23ms/step - loss: 5.6936 - val_loss: 1.0032
# Epoch 41/200
# 49/49 [==============================] - 1s 26ms/step - loss: 5.6891 - val_loss: 1.1877
# Epoch 42/200
# 49/49 [==============================] - 1s 28ms/step - loss: 5.6898 - val_loss: 1.0880
# Epoch 43/200
# 49/49 [==============================] - 1s 27ms/step - loss: 5.5764 - val_loss: 1.1051
# Epoch 44/200
# 49/49 [==============================] - 1s 28ms/step - loss: 5.5124 - val_loss: 1.0561
# Epoch 45/200
# 49/49 [==============================] - 1s 27ms/step - loss: 5.6029 - val_loss: 1.2507
# Epoch 46/200
# 49/49 [==============================] - 1s 29ms/step - loss: 5.5020 - val_loss: 1.1694
# Epoch 47/200
# 49/49 [==============================] - 1s 28ms/step - loss: 5.4855 - val_loss: 1.1534
# Epoch 48/200
# 49/49 [==============================] - 1s 22ms/step - loss: 5.5819 - val_loss: 1.0712
# Epoch 49/200
# 49/49 [==============================] - 1s 24ms/step - loss: 5.4495 - val_loss: 1.1829
# Epoch 50/200
# 49/49 [==============================] - 1s 27ms/step - loss: 5.3610 - val_loss: 1.0522
# c:\Users\Yuhui Lin\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# C:\Users\Yuhui Lin\AppData\Local\Temp\ipykernel_25944\157111123.py:89: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df['event_name_1_lag'] = df.groupby('id')['event_name_1'].shift(lag)
# Epoch 1/200
# 49/49 [==============================] - 3s 20ms/step - loss: 9.8606 - val_loss: 1.6943
# Epoch 2/200
# 49/49 [==============================] - 1s 16ms/step - loss: 7.7097 - val_loss: 1.6598
# Epoch 3/200
# 49/49 [==============================] - 1s 16ms/step - loss: 7.0522 - val_loss: 2.0403
# Epoch 4/200
# 49/49 [==============================] - 1s 16ms/step - loss: 6.6172 - val_loss: 1.7199
# Epoch 5/200
# 49/49 [==============================] - 1s 16ms/step - loss: 6.3928 - val_loss: 1.5855
# Epoch 6/200
# 49/49 [==============================] - 1s 16ms/step - loss: 6.0465 - val_loss: 1.5118
# Epoch 7/200
# 49/49 [==============================] - 1s 16ms/step - loss: 5.9315 - val_loss: 1.7378
# Epoch 8/200
# 49/49 [==============================] - 1s 15ms/step - loss: 5.8586 - val_loss: 1.5587
# Epoch 9/200
# 49/49 [==============================] - 1s 16ms/step - loss: 5.6261 - val_loss: 1.6729
# Epoch 10/200
# 49/49 [==============================] - 1s 15ms/step - loss: 5.4841 - val_loss: 1.7087
# Epoch 11/200
# 49/49 [==============================] - 1s 15ms/step - loss: 5.5882 - val_loss: 1.7596
# Epoch 12/200
# 49/49 [==============================] - 1s 16ms/step - loss: 5.5174 - val_loss: 1.6927
# Epoch 13/200
# 49/49 [==============================] - 1s 16ms/step - loss: 5.2228 - val_loss: 1.6393
# Epoch 14/200
# 49/49 [==============================] - 1s 16ms/step - loss: 5.2083 - val_loss: 1.9880
# Epoch 15/200
# 49/49 [==============================] - 1s 15ms/step - loss: 5.1619 - val_loss: 1.6764
# Epoch 16/200
# 49/49 [==============================] - 1s 16ms/step - loss: 5.0184 - val_loss: 1.5318
# Epoch 17/200
# 49/49 [==============================] - 1s 17ms/step - loss: 4.9945 - val_loss: 1.4918
# Epoch 18/200
# 49/49 [==============================] - 1s 16ms/step - loss: 4.9721 - val_loss: 1.6574
# Epoch 19/200
# 49/49 [==============================] - 1s 15ms/step - loss: 4.9914 - val_loss: 1.5940
# Epoch 20/200
# 49/49 [==============================] - 1s 15ms/step - loss: 4.8350 - val_loss: 1.5728
# Epoch 21/200
# 49/49 [==============================] - 1s 16ms/step - loss: 4.7774 - val_loss: 1.5543
# Epoch 22/200
# 49/49 [==============================] - 1s 16ms/step - loss: 4.8498 - val_loss: 1.8821
# Epoch 23/200
# 49/49 [==============================] - 1s 16ms/step - loss: 4.7863 - val_loss: 1.6346
# Epoch 24/200
# 49/49 [==============================] - 1s 15ms/step - loss: 4.7183 - val_loss: 1.5305
# Epoch 25/200
# 49/49 [==============================] - 1s 15ms/step - loss: 4.6578 - val_loss: 1.5906
# Epoch 26/200
# 49/49 [==============================] - 1s 16ms/step - loss: 4.7267 - val_loss: 1.7559
# Epoch 27/200
# 49/49 [==============================] - 1s 17ms/step - loss: 4.6473 - val_loss: 1.6526
# Epoch 28/200
# 49/49 [==============================] - 1s 16ms/step - loss: 4.7824 - val_loss: 2.0110
# Epoch 29/200
# 49/49 [==============================] - 1s 16ms/step - loss: 4.5920 - val_loss: 2.0291
# Epoch 30/200
# 49/49 [==============================] - 1s 16ms/step - loss: 4.5612 - val_loss: 1.7021
# Epoch 31/200
# 49/49 [==============================] - 1s 16ms/step - loss: 4.4916 - val_loss: 1.7038
# Epoch 32/200
# 49/49 [==============================] - 1s 17ms/step - loss: 4.4520 - val_loss: 1.5351
# Epoch 33/200
# 49/49 [==============================] - 1s 18ms/step - loss: 4.4457 - val_loss: 1.5855
# Epoch 34/200
# 49/49 [==============================] - 1s 18ms/step - loss: 4.3400 - val_loss: 1.5869
# Epoch 35/200
# 49/49 [==============================] - 1s 18ms/step - loss: 4.3565 - val_loss: 1.6655
# Epoch 36/200
# 49/49 [==============================] - 1s 18ms/step - loss: 4.3440 - val_loss: 1.5513
# Epoch 37/200
# 49/49 [==============================] - 1s 19ms/step - loss: 4.3427 - val_loss: 2.0008
# c:\Users\Yuhui Lin\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# C:\Users\Yuhui Lin\AppData\Local\Temp\ipykernel_25944\157111123.py:89: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df['event_name_1_lag'] = df.groupby('id')['event_name_1'].shift(lag)
# Epoch 1/200
# 49/49 [==============================] - 2s 19ms/step - loss: 22.8996 - val_loss: 2.9360
# Epoch 2/200
# 49/49 [==============================] - 1s 15ms/step - loss: 18.2328 - val_loss: 2.5922
# Epoch 3/200
# 49/49 [==============================] - 1s 15ms/step - loss: 16.5135 - val_loss: 2.7384
# Epoch 4/200
# 49/49 [==============================] - 1s 15ms/step - loss: 15.5983 - val_loss: 2.6820
# Epoch 5/200
# 49/49 [==============================] - 1s 15ms/step - loss: 14.7699 - val_loss: 2.9302
# Epoch 6/200
# 49/49 [==============================] - 1s 15ms/step - loss: 14.4470 - val_loss: 3.2446
# Epoch 7/200
# 49/49 [==============================] - 1s 15ms/step - loss: 13.8365 - val_loss: 2.9324
# Epoch 8/200
# 49/49 [==============================] - 1s 15ms/step - loss: 13.3917 - val_loss: 2.9721
# Epoch 9/200
# 49/49 [==============================] - 1s 16ms/step - loss: 13.1266 - val_loss: 3.0113
# Epoch 10/200
# 49/49 [==============================] - 1s 15ms/step - loss: 12.8713 - val_loss: 3.3435
# Epoch 11/200
# 49/49 [==============================] - 1s 15ms/step - loss: 12.3157 - val_loss: 2.7809
# Epoch 12/200
# 49/49 [==============================] - 1s 15ms/step - loss: 12.0615 - val_loss: 3.0451
# Epoch 13/200
# 49/49 [==============================] - 1s 15ms/step - loss: 11.7255 - val_loss: 3.0845
# Epoch 14/200
# 49/49 [==============================] - 1s 15ms/step - loss: 12.3885 - val_loss: 5.1224
# Epoch 15/200
# 49/49 [==============================] - 1s 15ms/step - loss: 11.8318 - val_loss: 3.3518
# Epoch 16/200
# 49/49 [==============================] - 1s 15ms/step - loss: 11.4584 - val_loss: 3.9877
# Epoch 17/200
# 49/49 [==============================] - 1s 15ms/step - loss: 11.0025 - val_loss: 3.3270
# Epoch 18/200
# 49/49 [==============================] - 1s 16ms/step - loss: 10.9690 - val_loss: 3.0382
# Epoch 19/200
# 49/49 [==============================] - 1s 15ms/step - loss: 10.6596 - val_loss: 3.0121
# Epoch 20/200
# 49/49 [==============================] - 1s 15ms/step - loss: 10.6691 - val_loss: 3.5298
# Epoch 21/200
# 49/49 [==============================] - 1s 15ms/step - loss: 10.6290 - val_loss: 3.8412
# Epoch 22/200
# 49/49 [==============================] - 1s 15ms/step - loss: 9.7639 - val_loss: 3.9156
# c:\Users\Yuhui Lin\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# C:\Users\Yuhui Lin\AppData\Local\Temp\ipykernel_25944\157111123.py:89: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df['event_name_1_lag'] = df.groupby('id')['event_name_1'].shift(lag)
# Epoch 1/200
# 49/49 [==============================] - 6s 33ms/step - loss: 4.1946 - val_loss: 0.5569
# Epoch 2/200
# 49/49 [==============================] - 1s 25ms/step - loss: 3.3538 - val_loss: 0.5952
# Epoch 3/200
# 49/49 [==============================] - 1s 27ms/step - loss: 3.2094 - val_loss: 0.5430
# Epoch 4/200
# 49/49 [==============================] - 1s 28ms/step - loss: 3.0925 - val_loss: 0.4935
# Epoch 5/200
# 49/49 [==============================] - 1s 26ms/step - loss: 3.0227 - val_loss: 0.5508
# Epoch 6/200
# 49/49 [==============================] - 1s 28ms/step - loss: 2.8995 - val_loss: 0.6003
# Epoch 7/200
# 49/49 [==============================] - 1s 23ms/step - loss: 2.8780 - val_loss: 0.5765
# Epoch 8/200
# 49/49 [==============================] - 1s 26ms/step - loss: 2.8432 - val_loss: 0.5105
# Epoch 9/200
# 49/49 [==============================] - 1s 26ms/step - loss: 2.7407 - val_loss: 0.4989
# Epoch 10/200
# 49/49 [==============================] - 1s 27ms/step - loss: 2.7251 - val_loss: 0.4855
# Epoch 11/200
# 49/49 [==============================] - 1s 26ms/step - loss: 2.6476 - val_loss: 0.4866
# Epoch 12/200
# 49/49 [==============================] - 1s 26ms/step - loss: 2.6997 - val_loss: 0.4899
# Epoch 13/200
# 49/49 [==============================] - 1s 27ms/step - loss: 2.5978 - val_loss: 0.4952
# Epoch 14/200
# 49/49 [==============================] - 1s 24ms/step - loss: 2.5884 - val_loss: 0.5334
# Epoch 15/200
# 49/49 [==============================] - 1s 27ms/step - loss: 2.5555 - val_loss: 0.4897
# Epoch 16/200
# 49/49 [==============================] - 1s 27ms/step - loss: 2.5270 - val_loss: 0.4783
# Epoch 17/200
# 49/49 [==============================] - 1s 27ms/step - loss: 2.5168 - val_loss: 0.4938
# Epoch 18/200
# 49/49 [==============================] - 1s 27ms/step - loss: 2.5008 - val_loss: 0.5123
# Epoch 19/200
# 49/49 [==============================] - 1s 27ms/step - loss: 2.4652 - val_loss: 0.5328
# Epoch 20/200
# 49/49 [==============================] - 1s 25ms/step - loss: 2.4130 - val_loss: 0.4821
# Epoch 21/200
# 49/49 [==============================] - 1s 27ms/step - loss: 2.4193 - val_loss: 0.4986
# Epoch 22/200
# 49/49 [==============================] - 1s 27ms/step - loss: 2.3816 - val_loss: 0.4797
# Epoch 23/200
# 49/49 [==============================] - 1s 27ms/step - loss: 2.3370 - val_loss: 0.4895
# Epoch 24/200
# 49/49 [==============================] - 1s 26ms/step - loss: 2.3520 - val_loss: 0.5335
# Epoch 25/200
# 49/49 [==============================] - 1s 23ms/step - loss: 2.2879 - val_loss: 0.4880
# Epoch 26/200
# 49/49 [==============================] - 1s 24ms/step - loss: 2.2510 - val_loss: 0.5010
# Epoch 27/200
# 49/49 [==============================] - 1s 26ms/step - loss: 2.2677 - val_loss: 0.4747
# Epoch 28/200
# 49/49 [==============================] - 1s 28ms/step - loss: 2.2361 - val_loss: 0.4796
# Epoch 29/200
# 49/49 [==============================] - 1s 30ms/step - loss: 2.2080 - val_loss: 0.4961
# Epoch 30/200
# 49/49 [==============================] - 1s 29ms/step - loss: 2.1814 - val_loss: 0.4754
# Epoch 31/200
# 49/49 [==============================] - 1s 28ms/step - loss: 2.1618 - val_loss: 0.4843
# Epoch 32/200
# 49/49 [==============================] - 1s 28ms/step - loss: 2.1540 - val_loss: 0.4886
# Epoch 33/200
# 49/49 [==============================] - 1s 29ms/step - loss: 2.1596 - val_loss: 0.5084
# Epoch 34/200
# 49/49 [==============================] - 1s 29ms/step - loss: 2.1455 - val_loss: 0.4740
# Epoch 35/200
# 49/49 [==============================] - 1s 27ms/step - loss: 2.1473 - val_loss: 0.4696
# Epoch 36/200
# 49/49 [==============================] - 1s 28ms/step - loss: 2.1289 - val_loss: 0.5298
# Epoch 37/200
# 49/49 [==============================] - 1s 28ms/step - loss: 2.1099 - val_loss: 0.4728
# Epoch 38/200
# 49/49 [==============================] - 1s 28ms/step - loss: 2.1001 - val_loss: 0.4926
# Epoch 39/200
# 49/49 [==============================] - 1s 27ms/step - loss: 2.0941 - val_loss: 0.4976
# Epoch 40/200
# 49/49 [==============================] - 1s 28ms/step - loss: 2.0888 - val_loss: 0.4983
# Epoch 41/200
# 49/49 [==============================] - 1s 26ms/step - loss: 2.0868 - val_loss: 0.4759
# Epoch 42/200
# 49/49 [==============================] - 1s 27ms/step - loss: 2.0897 - val_loss: 0.5153
# Epoch 43/200
# 49/49 [==============================] - 1s 28ms/step - loss: 2.0409 - val_loss: 0.4720
# Epoch 44/200
# 49/49 [==============================] - 1s 28ms/step - loss: 2.0574 - val_loss: 0.4762
# Epoch 45/200
# 49/49 [==============================] - 1s 30ms/step - loss: 2.0478 - val_loss: 0.4703
# Epoch 46/200
# 49/49 [==============================] - 1s 27ms/step - loss: 2.0478 - val_loss: 0.4699
# Epoch 47/200
# 49/49 [==============================] - 1s 24ms/step - loss: 2.0652 - val_loss: 0.4938
# Epoch 48/200
# 49/49 [==============================] - 1s 28ms/step - loss: 2.0270 - val_loss: 0.5045
# Epoch 49/200
# 49/49 [==============================] - 1s 26ms/step - loss: 2.1285 - val_loss: 0.5017
# Epoch 50/200
# 49/49 [==============================] - 1s 27ms/step - loss: 2.0806 - val_loss: 0.4923
# Epoch 51/200
# 49/49 [==============================] - 1s 26ms/step - loss: 2.0462 - val_loss: 0.4687
# Epoch 52/200
# 49/49 [==============================] - 1s 29ms/step - loss: 2.0193 - val_loss: 0.4718
# Epoch 53/200
# 49/49 [==============================] - 1s 27ms/step - loss: 2.0245 - val_loss: 0.4924
# Epoch 54/200
# 49/49 [==============================] - 1s 29ms/step - loss: 2.0186 - val_loss: 0.4691
# Epoch 55/200
# 49/49 [==============================] - 1s 29ms/step - loss: 2.0048 - val_loss: 0.4750
# Epoch 56/200
# 49/49 [==============================] - 1s 28ms/step - loss: 2.0227 - val_loss: 0.5076
# Epoch 57/200
# 49/49 [==============================] - 1s 29ms/step - loss: 2.0110 - val_loss: 0.4894
# Epoch 58/200
# 49/49 [==============================] - 1s 28ms/step - loss: 2.0048 - val_loss: 0.4814
# Epoch 59/200
# 49/49 [==============================] - 1s 29ms/step - loss: 1.9808 - val_loss: 0.4836
# Epoch 60/200
# 49/49 [==============================] - 1s 29ms/step - loss: 1.9838 - val_loss: 0.4950
# Epoch 61/200
# 49/49 [==============================] - 1s 30ms/step - loss: 1.9864 - val_loss: 0.4709
# Epoch 62/200
# 49/49 [==============================] - 1s 27ms/step - loss: 1.9803 - val_loss: 0.4764
# Epoch 63/200
# 49/49 [==============================] - 1s 28ms/step - loss: 2.0017 - val_loss: 0.5171
# Epoch 64/200
# 49/49 [==============================] - 1s 27ms/step - loss: 1.9614 - val_loss: 0.4709
# Epoch 65/200
# 49/49 [==============================] - 1s 27ms/step - loss: 1.9928 - val_loss: 0.4732
# Epoch 66/200
# 49/49 [==============================] - 1s 27ms/step - loss: 1.9599 - val_loss: 0.5271
# Epoch 67/200
# 49/49 [==============================] - 1s 27ms/step - loss: 1.9662 - val_loss: 0.4825
# Epoch 68/200
# 49/49 [==============================] - 1s 28ms/step - loss: 1.9677 - val_loss: 0.4747
# Epoch 69/200
# 49/49 [==============================] - 1s 27ms/step - loss: 1.9555 - val_loss: 0.4714
# Epoch 70/200
# 49/49 [==============================] - 1s 27ms/step - loss: 1.9764 - val_loss: 0.4775
# Epoch 71/200
# 49/49 [==============================] - 1s 27ms/step - loss: 1.9582 - val_loss: 0.4705
# c:\Users\Yuhui Lin\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# C:\Users\Yuhui Lin\AppData\Local\Temp\ipykernel_25944\157111123.py:89: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df['event_name_1_lag'] = df.groupby('id')['event_name_1'].shift(lag)
# Epoch 1/200
# 49/49 [==============================] - 5s 39ms/step - loss: 9.8832 - val_loss: 1.4592
# Epoch 2/200
# 49/49 [==============================] - 1s 31ms/step - loss: 7.2794 - val_loss: 1.3405
# Epoch 3/200
# 49/49 [==============================] - 1s 27ms/step - loss: 6.5462 - val_loss: 1.2739
# Epoch 4/200
# 49/49 [==============================] - 1s 28ms/step - loss: 6.0119 - val_loss: 1.3116
# Epoch 5/200
# 49/49 [==============================] - 1s 29ms/step - loss: 5.7410 - val_loss: 1.1866
# Epoch 6/200
# 49/49 [==============================] - 1s 25ms/step - loss: 5.1864 - val_loss: 1.1621
# Epoch 7/200
# 49/49 [==============================] - 1s 28ms/step - loss: 4.8292 - val_loss: 1.3564
# Epoch 8/200
# 49/49 [==============================] - 1s 30ms/step - loss: 4.7528 - val_loss: 1.0881
# Epoch 9/200
# 49/49 [==============================] - 1s 30ms/step - loss: 4.6716 - val_loss: 1.2845
# Epoch 10/200
# 49/49 [==============================] - 1s 29ms/step - loss: 4.7317 - val_loss: 1.0635
# Epoch 11/200
# 49/49 [==============================] - 1s 28ms/step - loss: 4.3634 - val_loss: 1.0345
# Epoch 12/200
# 49/49 [==============================] - 1s 27ms/step - loss: 4.2502 - val_loss: 1.2717
# Epoch 13/200
# 49/49 [==============================] - 1s 29ms/step - loss: 4.0909 - val_loss: 1.0142
# Epoch 14/200
# 49/49 [==============================] - 1s 28ms/step - loss: 4.0867 - val_loss: 1.0970
# Epoch 15/200
# 49/49 [==============================] - 1s 24ms/step - loss: 4.0881 - val_loss: 1.3698
# Epoch 16/200
# 49/49 [==============================] - 1s 25ms/step - loss: 3.8990 - val_loss: 1.3563
# Epoch 17/200
# 49/49 [==============================] - 1s 28ms/step - loss: 3.9732 - val_loss: 1.6347
# Epoch 18/200
# 49/49 [==============================] - 1s 28ms/step - loss: 4.3197 - val_loss: 1.3438
# Epoch 19/200
# 49/49 [==============================] - 1s 24ms/step - loss: 3.8586 - val_loss: 1.0867
# Epoch 20/200
# 49/49 [==============================] - 1s 29ms/step - loss: 3.7679 - val_loss: 1.1090
# Epoch 21/200
# 49/49 [==============================] - 1s 29ms/step - loss: 3.9645 - val_loss: 1.0700
# Epoch 22/200
# 49/49 [==============================] - 1s 22ms/step - loss: 3.7104 - val_loss: 1.1900
# Epoch 23/200
# 49/49 [==============================] - 1s 26ms/step - loss: 3.7374 - val_loss: 1.0811
# Epoch 24/200
# 49/49 [==============================] - 1s 29ms/step - loss: 3.8166 - val_loss: 1.2152
# Epoch 25/200
# 49/49 [==============================] - 1s 27ms/step - loss: 3.8475 - val_loss: 1.1890
# Epoch 26/200
# 49/49 [==============================] - 1s 29ms/step - loss: 3.8109 - val_loss: 1.2546
# Epoch 27/200
# 49/49 [==============================] - 1s 27ms/step - loss: 3.8131 - val_loss: 1.0837
# Epoch 28/200
# 49/49 [==============================] - 1s 28ms/step - loss: 3.7217 - val_loss: 1.4928
# Epoch 29/200
# 49/49 [==============================] - 1s 26ms/step - loss: 3.7044 - val_loss: 1.0319
# Epoch 30/200
# 49/49 [==============================] - 1s 24ms/step - loss: 3.5954 - val_loss: 1.0736
# Epoch 31/200
# 49/49 [==============================] - 1s 24ms/step - loss: 3.6052 - val_loss: 1.1169
# Epoch 32/200
# 49/49 [==============================] - 1s 23ms/step - loss: 3.6383 - val_loss: 1.0403
# Epoch 33/200
# 49/49 [==============================] - 1s 22ms/step - loss: 3.6366 - val_loss: 1.0238
# c:\Users\Yuhui Lin\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# C:\Users\Yuhui Lin\AppData\Local\Temp\ipykernel_25944\157111123.py:89: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df['event_name_1_lag'] = df.groupby('id')['event_name_1'].shift(lag)
# Epoch 1/200
# 49/49 [==============================] - 3s 20ms/step - loss: 13.6818 - val_loss: 1.3370
# Epoch 2/200
# 49/49 [==============================] - 1s 28ms/step - loss: 10.1609 - val_loss: 1.4905
# Epoch 3/200
# 49/49 [==============================] - 2s 33ms/step - loss: 9.0459 - val_loss: 1.1763
# Epoch 4/200
# 49/49 [==============================] - 1s 28ms/step - loss: 8.0279 - val_loss: 1.2665
# Epoch 5/200
# 49/49 [==============================] - 2s 32ms/step - loss: 7.4095 - val_loss: 1.3680
# Epoch 6/200
# 49/49 [==============================] - 1s 30ms/step - loss: 7.0057 - val_loss: 1.3911
# Epoch 7/200
# 49/49 [==============================] - 1s 31ms/step - loss: 6.8559 - val_loss: 1.6981
# Epoch 8/200
# 49/49 [==============================] - 2s 31ms/step - loss: 6.3590 - val_loss: 1.5663
# Epoch 9/200
# 49/49 [==============================] - 1s 30ms/step - loss: 6.2982 - val_loss: 1.2413
# Epoch 10/200
# 49/49 [==============================] - 2s 31ms/step - loss: 6.0064 - val_loss: 1.2846
# Epoch 11/200
# 49/49 [==============================] - 2s 31ms/step - loss: 5.7185 - val_loss: 1.9521
# Epoch 12/200
# 49/49 [==============================] - 2s 31ms/step - loss: 5.6657 - val_loss: 1.2053
# Epoch 13/200
# 49/49 [==============================] - 1s 28ms/step - loss: 5.5804 - val_loss: 1.4654
# Epoch 14/200
# 49/49 [==============================] - 1s 28ms/step - loss: 5.2831 - val_loss: 1.6656
# Epoch 15/200
# 49/49 [==============================] - 1s 29ms/step - loss: 5.4274 - val_loss: 1.2149
# Epoch 16/200
# 49/49 [==============================] - 1s 30ms/step - loss: 5.1094 - val_loss: 1.4227
# Epoch 17/200
# 49/49 [==============================] - 2s 31ms/step - loss: 4.9391 - val_loss: 1.3775
# Epoch 18/200
# 49/49 [==============================] - 2s 31ms/step - loss: 4.8648 - val_loss: 1.2401
# Epoch 19/200
# 49/49 [==============================] - 2s 32ms/step - loss: 4.7930 - val_loss: 1.1995
# Epoch 20/200
# 49/49 [==============================] - 1s 31ms/step - loss: 4.9306 - val_loss: 1.4289
# Epoch 21/200
# 49/49 [==============================] - 1s 30ms/step - loss: 4.8462 - val_loss: 1.4195
# Epoch 22/200
# 49/49 [==============================] - 1s 29ms/step - loss: 4.7467 - val_loss: 1.3466
# Epoch 23/200
# 49/49 [==============================] - 1s 26ms/step - loss: 4.6770 - val_loss: 1.5526
# c:\Users\Yuhui Lin\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# C:\Users\Yuhui Lin\AppData\Local\Temp\ipykernel_25944\157111123.py:89: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df['event_name_1_lag'] = df.groupby('id')['event_name_1'].shift(lag)
# Epoch 1/200
# 49/49 [==============================] - 2s 21ms/step - loss: 13.6947 - val_loss: 1.1763
# Epoch 2/200
# 49/49 [==============================] - 1s 15ms/step - loss: 10.3165 - val_loss: 1.2802
# Epoch 3/200
# 49/49 [==============================] - 1s 15ms/step - loss: 9.1126 - val_loss: 1.2608
# Epoch 4/200
# 49/49 [==============================] - 1s 15ms/step - loss: 8.1344 - val_loss: 1.2846
# Epoch 5/200
# 49/49 [==============================] - 1s 15ms/step - loss: 7.5752 - val_loss: 1.7842
# Epoch 6/200
# 49/49 [==============================] - 1s 15ms/step - loss: 7.4370 - val_loss: 1.5378
# Epoch 7/200
# 49/49 [==============================] - 1s 15ms/step - loss: 6.9854 - val_loss: 1.2289
# Epoch 8/200
# 49/49 [==============================] - 1s 15ms/step - loss: 6.7476 - val_loss: 1.3127
# Epoch 9/200
# 49/49 [==============================] - 1s 15ms/step - loss: 6.4628 - val_loss: 1.2933
# Epoch 10/200
# 49/49 [==============================] - 1s 15ms/step - loss: 6.5103 - val_loss: 1.1461
# Epoch 11/200
# 49/49 [==============================] - 1s 15ms/step - loss: 6.5539 - val_loss: 1.9077
# Epoch 12/200
# 49/49 [==============================] - 1s 15ms/step - loss: 6.2289 - val_loss: 1.1712
# Epoch 13/200
# 49/49 [==============================] - 1s 15ms/step - loss: 6.1001 - val_loss: 1.2601
# Epoch 14/200
# 49/49 [==============================] - 1s 15ms/step - loss: 6.0738 - val_loss: 1.2289
# Epoch 15/200
# 49/49 [==============================] - 1s 15ms/step - loss: 6.0133 - val_loss: 1.6908
# Epoch 16/200
# 49/49 [==============================] - 1s 15ms/step - loss: 5.9977 - val_loss: 1.2720
# Epoch 17/200
# 49/49 [==============================] - 1s 15ms/step - loss: 6.1606 - val_loss: 1.4814
# Epoch 18/200
# 49/49 [==============================] - 1s 15ms/step - loss: 5.9632 - val_loss: 1.3370
# Epoch 19/200
# 49/49 [==============================] - 1s 15ms/step - loss: 5.7878 - val_loss: 1.2637
# Epoch 20/200
# 49/49 [==============================] - 1s 15ms/step - loss: 5.7682 - val_loss: 1.5240
# Epoch 21/200
# 49/49 [==============================] - 1s 15ms/step - loss: 5.7685 - val_loss: 1.1302
# Epoch 22/200
# 49/49 [==============================] - 1s 15ms/step - loss: 5.4918 - val_loss: 1.1248
# Epoch 23/200
# 49/49 [==============================] - 1s 15ms/step - loss: 5.5569 - val_loss: 1.3228
# Epoch 24/200
# 49/49 [==============================] - 1s 15ms/step - loss: 5.3831 - val_loss: 1.2461
# Epoch 25/200
# 49/49 [==============================] - 1s 15ms/step - loss: 5.5316 - val_loss: 1.7088
# Epoch 26/200
# 49/49 [==============================] - 1s 16ms/step - loss: 5.3884 - val_loss: 1.1421
# Epoch 27/200
# 49/49 [==============================] - 1s 15ms/step - loss: 5.4442 - val_loss: 1.5349
# Epoch 28/200
# 49/49 [==============================] - 1s 15ms/step - loss: 5.9652 - val_loss: 1.3496
# Epoch 29/200
# 49/49 [==============================] - 1s 15ms/step - loss: 5.4824 - val_loss: 1.1639
# Epoch 30/200
# 49/49 [==============================] - 1s 15ms/step - loss: 5.3358 - val_loss: 1.3642
# Epoch 31/200
# 49/49 [==============================] - 1s 15ms/step - loss: 5.3692 - val_loss: 1.2601
# Epoch 32/200
# 49/49 [==============================] - 1s 15ms/step - loss: 5.1322 - val_loss: 1.2913
# Epoch 33/200
# 49/49 [==============================] - 1s 15ms/step - loss: 5.1242 - val_loss: 1.1280
# Epoch 34/200
# 49/49 [==============================] - 1s 15ms/step - loss: 5.0554 - val_loss: 1.2196
# Epoch 35/200
# 49/49 [==============================] - 1s 15ms/step - loss: 5.0250 - val_loss: 1.2521
# Epoch 36/200
# 49/49 [==============================] - 1s 15ms/step - loss: 5.0183 - val_loss: 1.1227
# Epoch 37/200
# 49/49 [==============================] - 1s 15ms/step - loss: 5.0326 - val_loss: 1.2061
# Epoch 38/200
# 49/49 [==============================] - 1s 15ms/step - loss: 4.9516 - val_loss: 1.1872
# Epoch 39/200
# 49/49 [==============================] - 1s 15ms/step - loss: 5.0129 - val_loss: 1.1151
# Epoch 40/200
# 49/49 [==============================] - 1s 15ms/step - loss: 4.9583 - val_loss: 1.2164
# Epoch 41/200
# 49/49 [==============================] - 1s 15ms/step - loss: 4.9585 - val_loss: 1.1599
# Epoch 42/200
# 49/49 [==============================] - 1s 15ms/step - loss: 4.9015 - val_loss: 1.3746
# Epoch 43/200
# 49/49 [==============================] - 1s 15ms/step - loss: 4.8278 - val_loss: 1.1657
# Epoch 44/200
# 49/49 [==============================] - 1s 15ms/step - loss: 4.7905 - val_loss: 1.2147
# Epoch 45/200
# 49/49 [==============================] - 1s 15ms/step - loss: 5.0039 - val_loss: 1.2199
# Epoch 46/200
# 49/49 [==============================] - 1s 15ms/step - loss: 4.7272 - val_loss: 1.1280
# Epoch 47/200
# 49/49 [==============================] - 1s 17ms/step - loss: 4.8169 - val_loss: 1.2056
# Epoch 48/200
# 49/49 [==============================] - 1s 17ms/step - loss: 4.6044 - val_loss: 1.1856
# Epoch 49/200
# 49/49 [==============================] - 1s 17ms/step - loss: 4.7838 - val_loss: 1.2557
# Epoch 50/200
# 49/49 [==============================] - 1s 17ms/step - loss: 4.6677 - val_loss: 1.1517
# Epoch 51/200
# 49/49 [==============================] - 1s 17ms/step - loss: 4.5393 - val_loss: 1.1756
# Epoch 52/200
# 49/49 [==============================] - 1s 17ms/step - loss: 4.6233 - val_loss: 1.1872
# Epoch 53/200
# 49/49 [==============================] - 1s 17ms/step - loss: 4.6578 - val_loss: 1.2130
# Epoch 54/200
# 49/49 [==============================] - 1s 17ms/step - loss: 4.5950 - val_loss: 1.1782
# Epoch 55/200
# 49/49 [==============================] - 1s 17ms/step - loss: 4.6618 - val_loss: 1.1736
# Epoch 56/200
# 49/49 [==============================] - 1s 18ms/step - loss: 4.5833 - val_loss: 1.1435
# Epoch 57/200
# 49/49 [==============================] - 1s 17ms/step - loss: 4.4649 - val_loss: 1.1543
# Epoch 58/200
# 49/49 [==============================] - 1s 17ms/step - loss: 4.6826 - val_loss: 1.3641
# Epoch 59/200
# 49/49 [==============================] - 1s 17ms/step - loss: 4.6678 - val_loss: 1.2971
# c:\Users\Yuhui Lin\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# C:\Users\Yuhui Lin\AppData\Local\Temp\ipykernel_25944\157111123.py:89: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df['event_name_1_lag'] = df.groupby('id')['event_name_1'].shift(lag)
# Epoch 1/200
# 49/49 [==============================] - 3s 20ms/step - loss: 6.1918 - val_loss: 0.8712
# Epoch 2/200
# 49/49 [==============================] - 1s 15ms/step - loss: 4.9581 - val_loss: 0.8488
# Epoch 3/200
# 49/49 [==============================] - 1s 15ms/step - loss: 4.6418 - val_loss: 0.9969
# Epoch 4/200
# 49/49 [==============================] - 1s 15ms/step - loss: 4.4005 - val_loss: 0.7891
# Epoch 5/200
# 49/49 [==============================] - 1s 15ms/step - loss: 4.1992 - val_loss: 0.8385
# Epoch 6/200
# 49/49 [==============================] - 1s 15ms/step - loss: 4.0563 - val_loss: 0.7806
# Epoch 7/200
# 49/49 [==============================] - 1s 15ms/step - loss: 3.9889 - val_loss: 0.7533
# Epoch 8/200
# 49/49 [==============================] - 1s 15ms/step - loss: 3.9185 - val_loss: 0.7782
# Epoch 9/200
# 49/49 [==============================] - 1s 15ms/step - loss: 3.8139 - val_loss: 0.7401
# Epoch 10/200
# 49/49 [==============================] - 1s 15ms/step - loss: 3.7752 - val_loss: 0.8958
# Epoch 11/200
# 49/49 [==============================] - 1s 15ms/step - loss: 3.6885 - val_loss: 0.7840
# Epoch 12/200
# 49/49 [==============================] - 1s 15ms/step - loss: 3.7049 - val_loss: 0.7303
# Epoch 13/200
# 49/49 [==============================] - 1s 15ms/step - loss: 3.6248 - val_loss: 0.7646
# Epoch 14/200
# 49/49 [==============================] - 1s 15ms/step - loss: 3.6137 - val_loss: 0.8424
# Epoch 15/200
# 49/49 [==============================] - 1s 15ms/step - loss: 3.5630 - val_loss: 0.7627
# Epoch 16/200
# 49/49 [==============================] - 1s 15ms/step - loss: 3.5144 - val_loss: 0.7557
# Epoch 17/200
# 49/49 [==============================] - 1s 15ms/step - loss: 3.6393 - val_loss: 0.8249
# Epoch 18/200
# 49/49 [==============================] - 1s 15ms/step - loss: 3.5312 - val_loss: 0.7440
# Epoch 19/200
# 49/49 [==============================] - 1s 15ms/step - loss: 3.4350 - val_loss: 0.8281
# Epoch 20/200
# 49/49 [==============================] - 1s 15ms/step - loss: 3.4538 - val_loss: 0.7579
# Epoch 21/200
# 49/49 [==============================] - 1s 16ms/step - loss: 3.3855 - val_loss: 0.7702
# Epoch 22/200
# 49/49 [==============================] - 1s 15ms/step - loss: 3.3893 - val_loss: 0.7630
# Epoch 23/200
# 49/49 [==============================] - 1s 15ms/step - loss: 3.3912 - val_loss: 0.7565
# Epoch 24/200
# 49/49 [==============================] - 1s 15ms/step - loss: 3.4040 - val_loss: 0.8082
# Epoch 25/200
# 49/49 [==============================] - 1s 15ms/step - loss: 3.2840 - val_loss: 0.7491
# Epoch 26/200
# 49/49 [==============================] - 1s 15ms/step - loss: 3.2884 - val_loss: 0.8202
# Epoch 27/200
# 49/49 [==============================] - 1s 15ms/step - loss: 3.3378 - val_loss: 0.8528
# Epoch 28/200
# 49/49 [==============================] - 1s 15ms/step - loss: 3.2865 - val_loss: 0.7327
# Epoch 29/200
# 49/49 [==============================] - 1s 15ms/step - loss: 3.1867 - val_loss: 0.8164
# Epoch 30/200
# 49/49 [==============================] - 1s 15ms/step - loss: 3.2571 - val_loss: 0.8515
# Epoch 31/200
# 49/49 [==============================] - 1s 15ms/step - loss: 3.1967 - val_loss: 0.8297
# Epoch 32/200
# 49/49 [==============================] - 1s 16ms/step - loss: 3.1670 - val_loss: 0.7459
# c:\Users\Yuhui Lin\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# C:\Users\Yuhui Lin\AppData\Local\Temp\ipykernel_25944\157111123.py:89: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df['event_name_1_lag'] = df.groupby('id')['event_name_1'].shift(lag)
# Epoch 1/200
# 49/49 [==============================] - 4s 30ms/step - loss: 24.8405 - val_loss: 2.1017
# Epoch 2/200
# 49/49 [==============================] - 1s 23ms/step - loss: 17.0609 - val_loss: 1.6289
# Epoch 3/200
# 49/49 [==============================] - 1s 22ms/step - loss: 14.8632 - val_loss: 1.7623
# Epoch 4/200
# 49/49 [==============================] - 1s 22ms/step - loss: 13.8447 - val_loss: 1.7610
# Epoch 5/200
# 49/49 [==============================] - 1s 22ms/step - loss: 13.3305 - val_loss: 1.4934
# Epoch 6/200
# 49/49 [==============================] - 1s 24ms/step - loss: 13.2043 - val_loss: 1.3879
# Epoch 7/200
# 49/49 [==============================] - 1s 22ms/step - loss: 12.6729 - val_loss: 1.4637
# Epoch 8/200
# 49/49 [==============================] - 1s 22ms/step - loss: 12.4564 - val_loss: 1.3675
# Epoch 9/200
# 49/49 [==============================] - 1s 22ms/step - loss: 13.1277 - val_loss: 1.3997
# Epoch 10/200
# 49/49 [==============================] - 1s 22ms/step - loss: 12.3523 - val_loss: 1.4320
# Epoch 11/200
# 49/49 [==============================] - 1s 22ms/step - loss: 12.1419 - val_loss: 1.3927
# Epoch 12/200
# 49/49 [==============================] - 1s 22ms/step - loss: 12.2160 - val_loss: 1.4710
# Epoch 13/200
# 49/49 [==============================] - 1s 22ms/step - loss: 11.9691 - val_loss: 1.5480
# Epoch 14/200
# 49/49 [==============================] - 1s 23ms/step - loss: 11.8691 - val_loss: 1.5278
# Epoch 15/200
# 49/49 [==============================] - 1s 22ms/step - loss: 11.7959 - val_loss: 1.9086
# Epoch 16/200
# 49/49 [==============================] - 1s 22ms/step - loss: 11.7705 - val_loss: 1.3246
# Epoch 17/200
# 49/49 [==============================] - 1s 22ms/step - loss: 11.5684 - val_loss: 1.3864
# Epoch 18/200
# 49/49 [==============================] - 1s 22ms/step - loss: 11.2052 - val_loss: 1.3982
# Epoch 19/200
# 49/49 [==============================] - 1s 22ms/step - loss: 11.2897 - val_loss: 1.5251
# Epoch 20/200
# 49/49 [==============================] - 1s 22ms/step - loss: 11.3501 - val_loss: 1.3251
# Epoch 21/200
# 49/49 [==============================] - 1s 22ms/step - loss: 10.9778 - val_loss: 1.5939
# Epoch 22/200
# 49/49 [==============================] - 1s 24ms/step - loss: 10.7807 - val_loss: 1.6889
# Epoch 23/200
# 49/49 [==============================] - 1s 22ms/step - loss: 10.6618 - val_loss: 1.6180
# Epoch 24/200
# 49/49 [==============================] - 1s 22ms/step - loss: 10.5894 - val_loss: 1.7253
# Epoch 25/200
# 49/49 [==============================] - 1s 22ms/step - loss: 10.6388 - val_loss: 1.5445
# Epoch 26/200
# 49/49 [==============================] - 1s 22ms/step - loss: 10.4192 - val_loss: 1.2629
# Epoch 27/200
# 49/49 [==============================] - 1s 22ms/step - loss: 10.0537 - val_loss: 1.6794
# Epoch 28/200
# 49/49 [==============================] - 1s 22ms/step - loss: 9.8801 - val_loss: 1.3362
# Epoch 29/200
# 49/49 [==============================] - 1s 22ms/step - loss: 9.8893 - val_loss: 1.2942
# Epoch 30/200
# 49/49 [==============================] - 1s 24ms/step - loss: 9.6218 - val_loss: 1.3180
# Epoch 31/200
# 49/49 [==============================] - 1s 22ms/step - loss: 9.6590 - val_loss: 2.0315
# Epoch 32/200
# 49/49 [==============================] - 1s 21ms/step - loss: 9.3919 - val_loss: 1.5949
# Epoch 33/200
# 49/49 [==============================] - 1s 22ms/step - loss: 9.2006 - val_loss: 1.3781
# Epoch 34/200
# 49/49 [==============================] - 1s 22ms/step - loss: 9.6671 - val_loss: 1.2942
# Epoch 35/200
# 49/49 [==============================] - 1s 21ms/step - loss: 9.0474 - val_loss: 1.7040
# Epoch 36/200
# 49/49 [==============================] - 1s 23ms/step - loss: 8.9966 - val_loss: 1.2961
# Epoch 37/200
# 49/49 [==============================] - 1s 21ms/step - loss: 8.8305 - val_loss: 1.6173
# Epoch 38/200
# 49/49 [==============================] - 1s 23ms/step - loss: 8.6322 - val_loss: 1.3332
# Epoch 39/200
# 49/49 [==============================] - 1s 22ms/step - loss: 8.6029 - val_loss: 1.5345
# Epoch 40/200
# 49/49 [==============================] - 1s 26ms/step - loss: 8.8456 - val_loss: 1.6509
# Epoch 41/200
# 49/49 [==============================] - 1s 25ms/step - loss: 8.6987 - val_loss: 1.2693
# Epoch 42/200
# 49/49 [==============================] - 1s 25ms/step - loss: 8.7235 - val_loss: 1.6193
# Epoch 43/200
# 49/49 [==============================] - 1s 25ms/step - loss: 8.4642 - val_loss: 1.6954
# Epoch 44/200
# 49/49 [==============================] - 1s 23ms/step - loss: 8.3073 - val_loss: 1.3010
# Epoch 45/200
# 49/49 [==============================] - 1s 25ms/step - loss: 8.3211 - val_loss: 1.3383
# Epoch 46/200
# 49/49 [==============================] - 1s 24ms/step - loss: 8.3279 - val_loss: 1.9419
# c:\Users\Yuhui Lin\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# C:\Users\Yuhui Lin\AppData\Local\Temp\ipykernel_25944\157111123.py:89: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df['event_name_1_lag'] = df.groupby('id')['event_name_1'].shift(lag)
# Epoch 1/200
# 49/49 [==============================] - 5s 35ms/step - loss: 15.1714 - val_loss: 0.9002
# Epoch 2/200
# 49/49 [==============================] - 1s 28ms/step - loss: 11.0595 - val_loss: 0.9717
# Epoch 3/200
# 49/49 [==============================] - 1s 24ms/step - loss: 9.7494 - val_loss: 1.3354
# Epoch 4/200
# 49/49 [==============================] - 1s 23ms/step - loss: 8.8912 - val_loss: 1.1319
# Epoch 5/200
# 49/49 [==============================] - 1s 26ms/step - loss: 8.2694 - val_loss: 1.4786
# Epoch 6/200
# 49/49 [==============================] - 1s 25ms/step - loss: 7.7970 - val_loss: 1.1435
# Epoch 7/200
# 49/49 [==============================] - 1s 23ms/step - loss: 7.5074 - val_loss: 1.2526
# Epoch 8/200
# 49/49 [==============================] - 1s 24ms/step - loss: 7.1575 - val_loss: 1.2441
# Epoch 9/200
# 49/49 [==============================] - 1s 27ms/step - loss: 7.0032 - val_loss: 0.9647
# Epoch 10/200
# 49/49 [==============================] - 1s 23ms/step - loss: 6.8502 - val_loss: 2.2744
# Epoch 11/200
# 49/49 [==============================] - 1s 23ms/step - loss: 6.6407 - val_loss: 1.0729
# Epoch 12/200
# 49/49 [==============================] - 1s 23ms/step - loss: 6.8499 - val_loss: 1.5031
# Epoch 13/200
# 49/49 [==============================] - 1s 23ms/step - loss: 6.2323 - val_loss: 1.2468
# Epoch 14/200
# 49/49 [==============================] - 1s 25ms/step - loss: 6.1069 - val_loss: 0.9447
# Epoch 15/200
# 49/49 [==============================] - 1s 22ms/step - loss: 5.9020 - val_loss: 0.8982
# Epoch 16/200
# 49/49 [==============================] - 1s 22ms/step - loss: 6.1281 - val_loss: 1.2115
# Epoch 17/200
# 49/49 [==============================] - 1s 22ms/step - loss: 5.6873 - val_loss: 1.5119
# Epoch 18/200
# 49/49 [==============================] - 1s 23ms/step - loss: 5.6598 - val_loss: 1.2376
# Epoch 19/200
# 49/49 [==============================] - 1s 22ms/step - loss: 5.6893 - val_loss: 1.1488
# Epoch 20/200
# 49/49 [==============================] - 1s 22ms/step - loss: 6.1821 - val_loss: 1.1419
# Epoch 21/200
# 49/49 [==============================] - 1s 24ms/step - loss: 5.6652 - val_loss: 0.9421
# Epoch 22/200
# 49/49 [==============================] - 1s 24ms/step - loss: 5.5470 - val_loss: 1.1730
# Epoch 23/200
# 49/49 [==============================] - 1s 24ms/step - loss: 6.0623 - val_loss: 0.9309
# Epoch 24/200
# 49/49 [==============================] - 1s 23ms/step - loss: 5.4706 - val_loss: 1.2570
# Epoch 25/200
# 49/49 [==============================] - 1s 23ms/step - loss: 5.3806 - val_loss: 1.2070
# Epoch 26/200
# 49/49 [==============================] - 1s 17ms/step - loss: 5.3640 - val_loss: 1.4157
# Epoch 27/200
# 49/49 [==============================] - 1s 17ms/step - loss: 5.2296 - val_loss: 0.8745
# Epoch 28/200
# 49/49 [==============================] - 1s 16ms/step - loss: 5.1980 - val_loss: 1.1385
# Epoch 29/200
# 49/49 [==============================] - 1s 16ms/step - loss: 5.3041 - val_loss: 0.9180
# Epoch 30/200
# 49/49 [==============================] - 1s 16ms/step - loss: 5.1437 - val_loss: 1.2762
# Epoch 31/200
# 49/49 [==============================] - 1s 16ms/step - loss: 5.0819 - val_loss: 0.9050
# Epoch 32/200
# 49/49 [==============================] - 1s 16ms/step - loss: 4.9893 - val_loss: 1.0645
# Epoch 33/200
# 49/49 [==============================] - 1s 16ms/step - loss: 5.1024 - val_loss: 1.0363
# Epoch 34/200
# 49/49 [==============================] - 1s 16ms/step - loss: 4.9720 - val_loss: 1.0604
# Epoch 35/200
# 49/49 [==============================] - 1s 16ms/step - loss: 4.8664 - val_loss: 1.0085
# Epoch 36/200
# 49/49 [==============================] - 1s 17ms/step - loss: 4.9286 - val_loss: 0.8927
# Epoch 37/200
# 49/49 [==============================] - 1s 16ms/step - loss: 5.1193 - val_loss: 1.0313
# Epoch 38/200
# 49/49 [==============================] - 1s 16ms/step - loss: 4.8296 - val_loss: 1.1214
# Epoch 39/200
# 49/49 [==============================] - 1s 16ms/step - loss: 5.0040 - val_loss: 0.9916
# Epoch 40/200
# 49/49 [==============================] - 1s 16ms/step - loss: 4.8520 - val_loss: 0.9536
# Epoch 41/200
# 49/49 [==============================] - 1s 16ms/step - loss: 4.6553 - val_loss: 1.1799
# Epoch 42/200
# 49/49 [==============================] - 1s 16ms/step - loss: 4.6482 - val_loss: 0.9648
# Epoch 43/200
# 49/49 [==============================] - 1s 16ms/step - loss: 4.6808 - val_loss: 0.9572
# Epoch 44/200
# 49/49 [==============================] - 1s 17ms/step - loss: 4.6722 - val_loss: 1.4103
# Epoch 45/200
# 49/49 [==============================] - 1s 17ms/step - loss: 4.6977 - val_loss: 1.1484
# Epoch 46/200
# 49/49 [==============================] - 1s 17ms/step - loss: 4.5353 - val_loss: 0.8828
# Epoch 47/200
# 49/49 [==============================] - 1s 17ms/step - loss: 4.5527 - val_loss: 1.0829
# c:\Users\Yuhui Lin\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import load_model

# Assuming df_test is your test dataframe
for store_id in STORES_IDS:
    columns = ['id'] + [f'F{i}' for i in range(1, 29)]
    df_test = pd.DataFrame(columns=columns)
    # Load the saved model
    model = load_model(f"transformer_model_{store_id}_12heads.h5")

    df, features = get_data_by_store(store_id)
    tensor_test, id = df_to_tensor_test(df, train_day=56)

    # Preprocess df_test to match the input shape expected by the model
    # Assuming you have a function preprocess_test_data() for this purpose


    # Make predictions
    predictions = model.predict(tensor_test)

    # Ensure predictions have shape (num_samples, 28)
    assert predictions.shape[1] == 28, "The model's output shape is not as expected"

    # Do something with the predictions, like save them to a dataframe or use them for further analysis
    # For example, if you want to add predictions to df_test
    df_test['id'] = id
    df_test.iloc[:,1:] = predictions

    df_test.to_csv(f"predicted_12heads_{store_id}",index=False)

# Now df_test contains predictions for each store
# Out:
# C:\Users\Yuhui Lin\AppData\Local\Temp\ipykernel_25944\157111123.py:89: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df['event_name_1_lag'] = df.groupby('id')['event_name_1'].shift(lag)
# 96/96 [==============================] - 1s 5ms/step
# C:\Users\Yuhui Lin\AppData\Local\Temp\ipykernel_25944\157111123.py:89: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df['event_name_1_lag'] = df.groupby('id')['event_name_1'].shift(lag)
# 96/96 [==============================] - 1s 5ms/step
# C:\Users\Yuhui Lin\AppData\Local\Temp\ipykernel_25944\157111123.py:89: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df['event_name_1_lag'] = df.groupby('id')['event_name_1'].shift(lag)
# 96/96 [==============================] - 1s 11ms/step
# C:\Users\Yuhui Lin\AppData\Local\Temp\ipykernel_25944\157111123.py:89: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df['event_name_1_lag'] = df.groupby('id')['event_name_1'].shift(lag)
# 96/96 [==============================] - 1s 5ms/step
# C:\Users\Yuhui Lin\AppData\Local\Temp\ipykernel_25944\157111123.py:89: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df['event_name_1_lag'] = df.groupby('id')['event_name_1'].shift(lag)
# 96/96 [==============================] - 1s 5ms/step
# C:\Users\Yuhui Lin\AppData\Local\Temp\ipykernel_25944\157111123.py:89: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df['event_name_1_lag'] = df.groupby('id')['event_name_1'].shift(lag)
# 96/96 [==============================] - 4s 11ms/step
# C:\Users\Yuhui Lin\AppData\Local\Temp\ipykernel_25944\157111123.py:89: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df['event_name_1_lag'] = df.groupby('id')['event_name_1'].shift(lag)
# 96/96 [==============================] - 1s 5ms/step
# C:\Users\Yuhui Lin\AppData\Local\Temp\ipykernel_25944\157111123.py:89: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df['event_name_1_lag'] = df.groupby('id')['event_name_1'].shift(lag)
# 96/96 [==============================] - 1s 11ms/step
# C:\Users\Yuhui Lin\AppData\Local\Temp\ipykernel_25944\157111123.py:89: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df['event_name_1_lag'] = df.groupby('id')['event_name_1'].shift(lag)
# 96/96 [==============================] - 1s 5ms/step
# C:\Users\Yuhui Lin\AppData\Local\Temp\ipykernel_25944\157111123.py:89: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df['event_name_1_lag'] = df.groupby('id')['event_name_1'].shift(lag)
# 96/96 [==============================] - 1s 5ms/step

# %%
import pandas as pd
columns = ['id'] + [f'F{i}' for i in range(1, 29)]
df_submission = pd.DataFrame(columns=columns)

for store_id in STORES_IDS:
    df_new = pd.read_csv(f"predicted_12heads_{store_id}")
    df_submission = pd.concat([df_submission,df_new],axis=0)

# Read the first CSV file
df1 = pd.read_csv("..\datasets\sample_submission.csv")

# Merge the two DataFrames on the 'id' column
merged_df = pd.merge(df1, df_submission, on='id', how="left", suffixes=('_original', ''))

# Replace values in columns F1 to F28 in df1 with corresponding values from df2
for col in df1.columns[1:]:
    merged_df[col+'_original'] = merged_df[col+'_original'].fillna(merged_df[col])

# Drop the extra columns
merged_df.drop(columns=[col+'_original' for col in df1.columns[1:]], inplace=True)
merged_df.fillna(0, inplace=True)

for column in merged_df.columns[1:]:
    # Replace negative values with zero
    merged_df[column] = merged_df[column].apply(lambda x: max(0, x) if isinstance(x, (int, float)) else x)
# Save the updated DataFrame to a new CSV file
merged_df.to_csv("merged_file_transformer_12heads.csv", index=False)
# Out:
# C:\Users\Yuhui Lin\AppData\Local\Temp\ipykernel_25944\3560863534.py:7: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_submission = pd.concat([df_submission,df_new],axis=0)
